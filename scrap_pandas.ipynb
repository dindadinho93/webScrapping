# %%
import pandas as pd
import requests
import ssl
import html5lib
import lxml

# %%
ssl.create_default_context = ssl._create_unverified_context

scraper = pd.read_html('https://en.wikipedia.org/wiki/The_World%27s_Billionaires')
scraper
# Out:
# [                                                    0  \
#  0   List of the world's billionaires, ranked in or...
#  1   The net worth of the world's billionaires incr...
#  2                                 Publication details
#  3                                           Publisher
#  4                                         Publication
#  5                                     First published
#  6                                  Latest publication
#  7                      Current list details (2021)[2]
#  8                                          Wealthiest
#  9                                     Net worth (1st)
#  10                             Number of billionaires
#  11                         Total list net worth value
#  12                            New members to the list
#  13           Forbes: The World's Billionaires website
#
#                                                      1
#  0   List of the world's billionaires, ranked in or...
# ...

# %%
for idx, table in enumerate(scraper):
    print('########################################################')
    print(idx)
    print(table)
# Out:
# ########################################################
# 0
#                                                     0  \
# 0   List of the world's billionaires, ranked in or...
# 1   The net worth of the world's billionaires incr...
# 2                                 Publication details
# 3                                           Publisher
# 4                                         Publication
# 5                                     First published
# 6                                  Latest publication
# 7                      Current list details (2021)[2]
# 8                                          Wealthiest
# 9                                     Net worth (1st)
# 10                             Number of billionaires
# 11                         Total list net worth value
# 12                            New members to the list
# 13           Forbes: The World's Billionaires website
#
#                                                     1
# ...

# %%
scraper[3].drop(columns='No.')
# Out:
#                        Name Net worth (USD)  Age    Nationality  \
# 0                Jeff Bezos    $113 billion   56  United States
# 1                Bill Gates     $98 billion   64  United States
# 2  Bernard Arnault & family     $76 billion   71         France
# 3            Warren Buffett   $67.5 billion   89  United States
# 4             Larry Ellison     $59 billion   75  United States
# 5            Amancio Ortega   $55.1 billion   84          Spain
# 6           Mark Zuckerberg   $54.7 billion   35  United States
# 7                Jim Walton   $54.6 billion   71  United States
# 8              Alice Walton   $54.4 billion   70  United States
# 9          S. Robson Walton   $54.1 billion   77  United States
#
#   Source(s) of wealth
# 0              Amazon
# 1           Microsoft
# 2                LVMH
# 3  Berkshire Hathaway
# 4  Oracle Corporation
# 5       Inditex, Zara
# 6      Facebook, Inc.
# 7             Walmart
# 8             Walmart
# 9             Walmart

# %%
scraper[10].drop(columns='No.')
# Out:
#                            Name Net worth (USD)  Age    Nationality  \
# 0          Carlos Slim & family   $73.0 billion   73         Mexico
# 1                    Bill Gates   $67.0 billion   57  United States
# 2                Amancio Ortega   $57.0 billion   76          Spain
# 3                Warren Buffett   $53.5 billion   82  United States
# 4                 Larry Ellison   $43.0 billion   68  United States
# 5                  Charles Koch   $34.0 billion   77  United States
# 6                    David Koch   $34.0 billion   72  United States
# 7                   Li Ka-shing   $31.0 billion   84      Hong Kong
# 8  Liliane Bettencourt & family   $30.0 billion   90         France
# 9               Bernard Arnault   $29.0 billion   63         France
#
#           Source(s) of wealth
# 0  América Móvil, Grupo Carso
# 1                   Microsoft
# 2               Inditex Group
# 3          Berkshire Hathaway
# 4          Oracle Corporation
# 5             Koch Industries
# ...

# %%
ssl.create_default_context = ssl._create_unverified_context

url = 'https://www.gsmarena.com/xiaomi_12-11285.php'
job_df = pd.read_html(url)
job_df
# Out:
# [          0           1                                                  2
#  0   Network  Technology                GSM / CDMA / HSPA / EVDO / LTE / 5G
#  1   Network    2G bands        GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2
#  2   Network         NaN                                           CDMA 800
#  3   Network    3G bands    HSDPA 800 / 850 / 900 / 1700(AWS) / 1900 / 2100
#  4   Network         NaN                                   CDMA2000 1xEV-DO
#  5   Network    4G bands  1, 2, 3, 4, 5, 7, 8, 12, 17, 18, 19, 26, 34, 3...
#  6   Network    5G bands              1, 3, 5, 8, 28, 41, 77, 78, 79 SA/NSA
#  7   Network       Speed                     HSPA 42.2/5.76 Mbps, LTE-A, 5G
#  8   Network         NaN                                                NaN
#  9   Network         NaN                                                NaN
#  10  Network         NaN                                                NaN
# ...

# %%
for idx, table in enumerate(job_df):
    print('########################################################')
    print(idx)
    print(table)
# Out:
# ########################################################
# 0
#           0           1                                                  2
# 0   Network  Technology                GSM / CDMA / HSPA / EVDO / LTE / 5G
# 1   Network    2G bands        GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2
# 2   Network         NaN                                           CDMA 800
# 3   Network    3G bands    HSDPA 800 / 850 / 900 / 1700(AWS) / 1900 / 2100
# 4   Network         NaN                                   CDMA2000 1xEV-DO
# 5   Network    4G bands  1, 2, 3, 4, 5, 7, 8, 12, 17, 18, 19, 26, 34, 3...
# 6   Network    5G bands              1, 3, 5, 8, 28, 41, 77, 78, 79 SA/NSA
# 7   Network       Speed                     HSPA 42.2/5.76 Mbps, LTE-A, 5G
# 8   Network         NaN                                                NaN
# 9   Network         NaN                                                NaN
# 10  Network         NaN                                                NaN
# ...

# %%
df = job_df[0].dropna()
df
# Out:
#          0           1                                                  2
# 0  Network  Technology                GSM / CDMA / HSPA / EVDO / LTE / 5G
# 1  Network    2G bands        GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2
# 3  Network    3G bands    HSDPA 800 / 850 / 900 / 1700(AWS) / 1900 / 2100
# 5  Network    4G bands  1, 2, 3, 4, 5, 7, 8, 12, 17, 18, 19, 26, 34, 3...
# 6  Network    5G bands              1, 3, 5, 8, 28, 41, 77, 78, 79 SA/NSA
# 7  Network       Speed                     HSPA 42.2/5.76 Mbps, LTE-A, 5G

# %%
df = job_df[3].dropna()
df
# Out:
#          0           1                                                  2
# 0  Display        Type  OLED, 1B colors, 120Hz, Dolby Vision, HDR10+, ...
# 1  Display        Size  6.28 inches, 95.2 cm2 (~89.2% screen-to-body r...
# 2  Display  Resolution  1080 x 2400 pixels, 20:9 ratio (~419 ppi density)
# 3  Display  Protection                       Corning Gorilla Glass Victus
